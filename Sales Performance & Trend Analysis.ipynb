# %% [markdown]
# # Data Understanding & Cleaning

# %%
import pandas as pd

# %% [markdown]
# ## Load dataset

# %%
df= pd.read_csv("C:/Users/jayat/Documents/sales project/data/Superstore.csv", encoding ='latin1')

# %% [markdown]
# ## View first 5 rows

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ## Check dataset info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# ## Check summary statistics

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# ## Check column names

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ## Missing Values

# %%
print(df.isnull().sum())
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# ## Duplicates

# %%
print(df.duplicated().sum())
df = df.drop_duplicates()
# Out:
# 0

# %% [markdown]
# ## Data Types Correction

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %% [markdown]
# ## Feature Engineering

# %%
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Quarter'] = df['Order Date'].dt.to_period('Q')

# %% [markdown]
# ## Verifying Data

# %%
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Basic Sales Insights

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Total sales, profit, orders
print("Total Sales:", df['Sales'].sum())
print("Total Profit:", df['Profit'].sum())
print("Total Orders:", df['Order ID'].nunique())
# Out:
# Total Sales: 2297200.8603000003
# Total Profit: 286397.0217
# Total Orders: 5009

# %% [markdown]
# ## Sales Over Time

# %%
# Monthly sales trend
monthly_sales = df.groupby(df['Order Date'].dt.to_period('M')).sum(numeric_only=True)['Sales']

monthly_sales.plot(kind='line', figsize=(12,6), marker='o')
plt.title("Monthly Sales Trend")
plt.ylabel("Sales")
plt.xlabel("Month")
plt.show()

# %% [markdown]
# ## Sales by Product Category

# %%
category_sales = df.groupby('Category')['Sales'].sum().sort_values(ascending=False)

sns.barplot(x=category_sales.values, y=category_sales.index, palette="viridis")
plt.title("Sales by Product Category")
plt.show()
# Out:
# C:\Users\jayat\AppData\Local\Temp\ipykernel_15624\1036582823.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_sales.values, y=category_sales.index, palette="viridis")

# %% [markdown]
# ## Sales by Customer Segment

# %%
segment_sales = df.groupby('Segment')['Sales'].sum()

sns.barplot(x=segment_sales.index, y=segment_sales.values, palette="mako")
plt.title("Sales by Customer Segment")
plt.show()
# Out:
# C:\Users\jayat\AppData\Local\Temp\ipykernel_15624\1332660380.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=segment_sales.index, y=segment_sales.values, palette="mako")

# %% [markdown]
# ## Sales by Region

# %%
region_sales = df.groupby('Region')['Sales'].sum().sort_values(ascending=False)

sns.barplot(x=region_sales.index, y=region_sales.values, palette="cubehelix")
plt.title("Sales by Region")
plt.show()
# Out:
# C:\Users\jayat\AppData\Local\Temp\ipykernel_15624\1995524361.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=region_sales.index, y=region_sales.values, palette="cubehelix")

# %% [markdown]
# ## Top 10 Products

# %%
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

sns.barplot(x=top_products.values, y=top_products.index, palette="plasma")
plt.title("Top 10 Products by Sales")
plt.show()
# Out:
# C:\Users\jayat\AppData\Local\Temp\ipykernel_15624\206349573.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_products.values, y=top_products.index, palette="plasma")

# %% [markdown]
# # Business Insights & Recommendations

# %% [markdown]
# ## Sales Trends Over Time

# %%
# Monthly Sales
monthly_sales = df.groupby(df['Order Date'].dt.to_period('M')).sum(numeric_only=True)['Sales']

# Display top 5 months by sales
print(monthly_sales.sort_values(ascending=False).head())

# Plot trend
monthly_sales.plot(kind='line', figsize=(12,6), marker='o')
plt.title("Monthly Sales Trend")
plt.ylabel("Sales")
plt.xlabel("Month")
plt.show()
# Out:
# Order Date
# 2017-11    118447.8250
# 2016-12     96999.0430
# 2017-09     87866.6520
# 2017-12     83829.3188
# 2014-09     81777.3508
# Freq: M, Name: Sales, dtype: float64

# %% [markdown]
# ## Sales by Product Category

# %%
category_sales = df.groupby('Category')[['Sales','Profit']].sum().sort_values('Sales', ascending=False)
print(category_sales)

sns.barplot(x=category_sales['Sales'], y=category_sales.index, palette="viridis")
plt.title("Sales by Product Category")
plt.show()
# Out:
#                        Sales       Profit
# Category
# Technology       836154.0330  145454.9481
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008
# C:\Users\jayat\AppData\Local\Temp\ipykernel_15624\3945682779.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_sales['Sales'], y=category_sales.index, palette="viridis")

# %% [markdown]
# ## Sales by Customer Segment

# %%
segment_sales = df.groupby('Segment')[['Sales','Profit']].sum()
print(segment_sales)

sns.barplot(x=segment_sales['Sales'], y=segment_sales.index, palette="mako")
plt.title("Sales by Customer Segment")
plt.show()
# Out:
#                     Sales       Profit
# Segment
# Consumer     1.161401e+06  134119.2092
# Corporate    7.061464e+05   91979.1340
# Home Office  4.296531e+05   60298.6785
# C:\Users\jayat\AppData\Local\Temp\ipykernel_15624\1769443318.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=segment_sales['Sales'], y=segment_sales.index, palette="mako")

# %% [markdown]
# ## Sales by Region

# %%
region_sales = df.groupby('Region')[['Sales','Profit']].sum().sort_values('Sales', ascending=False)
print(region_sales)

sns.barplot(x=region_sales['Sales'], y=region_sales.index, palette="cubehelix")
plt.title("Sales by Region")
plt.show()
# Out:
#                Sales       Profit
# Region
# West     725457.8245  108418.4489
# East     678781.2400   91522.7800
# Central  501239.8908   39706.3625
# South    391721.9050   46749.4303
# C:\Users\jayat\AppData\Local\Temp\ipykernel_15624\2522555985.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=region_sales['Sales'], y=region_sales.index, palette="cubehelix")

# %% [markdown]
# ## Top Products

# %%
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)
print(top_products)

sns.barplot(x=top_products.values, y=top_products.index, palette="plasma")
plt.title("Top 10 Products by Sales")
plt.show()
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64
# ...

# %% [markdown]
# ## Profitability Analysis

# %%
profitability = df.groupby('Category')[['Sales','Profit']].sum()
print(profitability)

# Profit vs Sales Scatter
sns.scatterplot(x='Sales', y='Profit', hue='Category', data=df)
plt.title("Profit vs Sales by Category")
plt.show()
# Out:
#                        Sales       Profit
# Category
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008
# Technology       836154.0330  145454.9481
